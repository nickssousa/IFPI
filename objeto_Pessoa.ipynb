# %% [markdown]
# <a href="https://colab.research.google.com/github/nickssousa/IFPI/blob/POO/objeto_Pessoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Crie uma classe que modele uma Pessoa. Utilizar todos os conceitos abordados até aqui (construtores,
# parâmetros opcionais, encapsulamento, decoradores em python).
#
#
# Atributos: nome, idade, peso, altura (cm), sexo(M/F), estado(vivo/morto),
# estado_civil(solteiro/ casado/viúvo), conjuge.
#
#
# Considerar como opcionais os atributos: estado(vivo/morto (padrão: vivo)),
# estado_civil(solteiro/ casado/viúvo (padrão: solteiro)), conjuge (padrão: None). Métodos:
#
# - envelhecer: atualizar em um ano a idade da pessoa. A cada ano que nossa pessoa envelhece, sendo a idade
# dela menor que 21 anos, ela deve crescer 0,5 cm
#
# - engordar: somar o peso atual da pessoa ao argumento valor do método.
#
# - emagrecer: subtrair o peso atual da pessoa ao argumento valor do método
#
# - crescer: somar à altura atual da pessoa o valor que está no argumento do método, somente se a pessoa tiver
# até 21 anos de idade.
#
# - casar: mudar o estado civil da pessoa (self) para “casado(a)” e atribuir ao valor do atributo conjuge o objeto (pessoa)
# com quem a pessoa está se casando; Não permitir que pessoas casadas se casem novamente e não permitir que
# pessoas menores de idade se casem.
#
# - morrer: mudar o atributo estado da pessoa para “morto”. Nenhum dos métodos anteriores poderá ser
# executado se a pessoa estiver morta.
#
#
# Execução:
#
# Criar várias pessoas (objetos) com atributos variados. Testar todos os métodos. Colocar mensagens em cada método (prints)
#
# - Crie um objeto de nome:maria com os seguintes atributos:
# Nome: “Maria”
# Idade:5
# Peso:20
# Altura:100
# Sexo: ‘F’
#
# - Crie um objeto de nome: joão com os seguintes atributos:
#  Nome:“João”
# Idade:12
# Peso: 40
# Altura: 140
# Sexo: ‘M’
#
# - Crie um objeto de nome: pedro com os seguintes atributos:
#  Nome: “Pedro”
# Idade: 22
# Peso:65
# Altura: 170
# Sexo: ‘M’
# - Crie um objeto de nome bia com os seguintes atributos:
#  Nome:“Bia”
# Idade: 18
# peso: 55
# altura: 160
# Sexo: ‘F’
#
# - Crie um objeto de nome julia com os seguintes atributos:
#  nome:“Julia”
#
# idade: 30
#
# peso: 65
#
# altura: 170
#
# sexo: ‘F’
#
#
# - Crie um objeto de nome cadu com os seguintes atributos:
#  nome: “Carlos”
#
# idade: 2
#
# peso: 11
#
# altura: 80
#
# sexo: ‘M’
#
#
# - Crie um objeto de nome: Jonas com os seguintes atributos:
#  Nome:“Jonas”
#
# Idade: 34
#
# Peso:70
#
# Altura: 180
#
# Sexo:’M’
#
# Realize as operações abaixo:
#
# a) atribua a idade de maria para o valor: 10
#
# Mensagem: “sem permissão”
#
# b) Maria fez aniversário. Chame o método necessário.
#
# Mensagem: “Maria está com 6 anos e 105 cm de altura”.
#
# c) Pedro quer crescer 2 cm. Chame o método necessário.
#
#  Mensagem:“Pedro não pode mais crescer pois está com 21 anos ou mais”
#
# d) Bia quer casar com Carlos. Chame o método necessário.
#
# Mensagem: “Casamento não permitido. Carlos é de menor.
# ”.
#
# e) Pedro quer casar com Maria. Chame o método
# necessário.
#  Mensagem: “Casamento não permitido. Maria é
# de menor”.
#
# f) Pedro quer casar com Júlia.
#
# Mensagem: “Pedro está casado com Júlia”.
#
# g) Pedro quer casar com Bia.
#
# Mensagem: “Casamento não realizado. Pedro é casado.”
#
# h) Maria morreu.
#
# Mensagem: “Maria morreu”.
#
# i) Maria quer engordar.
#
# Mensagem: “Operação não realizada. Maria está morta”.
#
# j) Bia quer casar com Jonas.
#
# Mensagem: “Bia está casada com Jonas”
#
# k) Bia morreu.
#
# Mensagem: “Bia morreu”
#
# l) Pedro Morreu
#
# Mensagem: “Pedro Morreu”
#
# m) Jonas quer casar com Júlia
#
# Mensagem: “Jonas está casado com Júlia”
#
# n) Pedro quer casar com Bia
#
# Mensagem: “Casamento não realizado. Pedro está morto.”
#
# o) Mostre a idade de Pedro.
#
# Mensagem: “Pedro está morto”.
#
# p) Atribua a idade de João para: 50
#
# Mensagem: “sem permissão”

# %%
class pessoa():
    def __init__(self, nome, idade, peso, altura, sexo, estado_civil = "Solteiro(a)"):
        self.__nome = nome #SÓ GET
        self.__idade = idade #SÓ GET
        self.__peso = peso #SÓ GET
        self.__altura = altura #SÓ GET
        self.__sexo = sexo #SÓ GET
        self.__estado = 'Vivo' #SÓ GET
        self.__estado_civil = estado_civil #SÓ GET
        self.__conjuge = None #SÓ GET

    @property
    def nome(self):
      return self.__nome
    
    @nome.setter
    def nome(self, novo_nome):
        print("Você não pode alterar o nome.")
      
    @property
    def idade(self):
      if self.__estado == 'Morto':
           print("Pedro está morto.")
           return
      return self.__idade
    
    @idade.setter
    def idade(self, nova_idade):
        print("Você não pode alterar a idade.")

    @property
    def peso(self):
       if self.__estado == 'Morto':
           print("Pedro está morto.")
           return
       return self.__peso
    
    @peso.setter
    def peso(self, novo_peso):
        print("Você não pode alterar o peso.")

    @property
    def altura(self):
      return self.__altura
    
    @altura.setter
    def nome(self, nova_altura):
        print("Você não pode alterar a altura.")

    @property
    def sexo(self):
      return self.__sexo
    
    @sexo.setter
    def sexo(self, novo_sexo):
        print("Você não pode alterar o sexo.")

    @property
    def estado(self):
      return self.__estado
    
    @estado.setter
    def estado(self, novo_estado):
        print("Você não pode alterar o estado dessa forma. Utilize o método morrer().")

    @property
    def estado_civil(self):
      return self.__estado_civil
    
    @property
    def conjuge(self):
      return self.__conjuge
    
    @conjuge.setter
    def conjuge(self, novo_conjuge):
        print("Você não pode alterar o conjuge.")

    def envelhecer(self):
      if self.__estado == 'Vivo':
        self.__idade += 1
        if self.__idade <= 21:
          self.__altura += 0.5
          print(f'{self.__nome} agora está com {self.__idade} anos e está com {self.__altura} cm')
        else:
          print(f'{self.__nome} está com {self.__idade} anos e não pode mais crescer.')
      else:
        print(f'{self.__nome} morreu.')


    def engordar(self, valor):
      if self.__estado == 'Vivo':
        self.__peso+= valor
        print(f'ela agora está com {self.__peso} Kg.')
      else:
        print(f'{self.__nome} não pode engordar pois não está vivo(a).')
      
    def emagrecer(self, valor):
      if self.__estado == 'Vivo':
        self.__peso-= valor
        print(f'ela agora está com {self.__peso} Kg.')
      else:
        print(f'{self.__nome} morreu.')

  #crescer: somar à altura atual da pessoa o valor que está no argumento do método, somente se a pessoa tiver até 21 anos de idade.
    def crescer(self, valor):
      if self.__estado == 'Vivo':
        soma= 0
        if self.__idade <= 21:
          while soma< valor:
            self.__altura += 0.5
            soma+= 0.5
          print(f'{self.__nome} agora está com {self.__altura} cm de altura.')
        else:
          print(f'{self.__nome} não pode mais crescer.')

      else:
        print(f'{self.__nome} morreu.')

      
  #morrer: mudar o atributo estado da pessoa para “morto”. Nenhum dos métodos anteriores poderá ser executado se a pessoa estiver morta.
    def morrer(self):
      if self.__estado == 'Vivo':
        self.__estado = 'Morto'
        print(f'{self.__nome} morreu.')
        if self.__conjuge != None:
            conjuge= self.__conjuge
            if conjuge.estado == 'Vivo':
              conjuge.__estado_civil= "viúvo"

      else:
        print(f'{self.__nome} já está morto.')

  #casar: mudar o estado civil da pessoa (self) para “casado(a)” e atribuir ao valor do atributo conjuge o objeto (pessoa) com quem a pessoa está se casando;
  #Não permitir que pessoas casadas se casem novamente e não permitir que pessoas menores de idade se casem.
    def casar(self, conjuge):
      if type(conjuge) == pessoa:
        if self.__estado == 'Vivo' and conjuge.estado == 'Vivo':
          if self.__estado_civil != 'Casado(a)' and conjuge.estado_civil != "Casado(a)":
            if self.__idade >= 18 and conjuge.idade >= 18:
              print("Casamento realizado com sucesso!")
              self.__estado_civil= 'Casado(a)'
              self.__conjuge= conjuge
              conjuge.__conjuge= self
              conjuge.__estado_civil= 'Casado(a)'
              print(f'{self.__nome} casou com {conjuge.__nome}')
           
            else:
              print("Casamento não realizado!")
          else:
              print("Casamento não realizado!")
        else:
              print("Casamento não realizado!")
      else:
        print("Erro ao casar!")

    def divorciar(self, conjuge):
      if self.__estado == 'Vivo' and self.__estado_civil== 'Casado(a)':
        conjuge= self.__conjuge
        if conjuge.estado == 'Vivo':
          conjuge.__estado_civil == 'Divorciado(a)'
          self.__estado_civil = 'Divorciado(a)'
          print('divorcio realizado')
        else:
          print(f'{conjuge.nome} está morto')
      else:
        print(f'{self.nome} está morto')

Maria= pessoa("Maria", 5, 20.0, 100.0, 'F')
João = pessoa("João", 12, 40.0, 140.0, 'M')
Pedro = pessoa("Pedro", 22, 65.0, 170.0, 'M')
Bia = pessoa("Bia", 18, 55.0, 160.0, 'F')
Julia = pessoa("Julia", 30, 65.0, 170.0, 'F')
Carlos = pessoa("Carlos", 2, 11.0, 80.0, 'M')
Jonas = pessoa("Jonas", 34, 70.0, 180.0, 'M')



Maria.idade = 10
Maria.envelhecer()

Pedro.crescer(2)
Pedro.casar(Maria)

Pedro.casar(Julia)


Pedro.casar(Bia)

Maria.morrer()
Maria.engordar(5.0)

Bia.casar(Jonas)
Bia.morrer()

Pedro.morrer()

Jonas.casar(Julia)
Pedro.casar(Bia)

Pedro.idade
João.idade = 50
# Out:
# Você não pode alterar a idade.
# Maria agora está com 6 anos e está com 100.5 cm
# Pedro não pode mais crescer.
# Casamento não realizado!
# Casamento realizado com sucesso!
# Pedro casou com Julia
# Casamento não realizado!
# Maria morreu.
# Maria não pode engordar pois não está vivo(a).
# Casamento realizado com sucesso!
# Bia casou com Jonas
# Bia morreu.
# Pedro morreu.
# Casamento realizado com sucesso!
# Jonas casou com Julia
# Casamento não realizado!
# Pedro está morto.
# Você não pode alterar a idade.
